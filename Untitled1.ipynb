# %%
import waProcessing as wp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f633c9e3c203> in <module>()
# ----> 1 import waProcessing as wp
#
# ImportError: No module named 'waProcessing'

# %%
import wavProcessing as wp

# %%
sampleAudioDirectory = './Sample Audio'

# %%
 audioFiles = wp.get_audio_from_dir(sampleAudioDirectory)

# %%
print audioFiles
# Out:
#   File "<ipython-input-5-3d5031a674cf>", line 1
#     print audioFiles
#                    ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print(audioFiles)
# Out:
# ['carnatic.wav', 'mridangam.wav', 'cello-double-2.wav', 'multiSines.wav', 'cello-double.wav']

# %%
wp.fft_and_blocks(audioFiles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d2674069e584> in <module>()
# ----> 1 wp.fft_and_blocks(audioFiles)
#
# TypeError: fft_and_blocks() missing 1 required positional argument: 'sampleAudioDirectory'

# %%
wp.fft_and_blocks(audioFiles, sampleAudioDirectory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-8d18d4ae304f> in <module>()
# ----> 1 wp.fft_and_blocks(audioFiles, sampleAudioDirectory)
#
# /home/as497/codework/wav-processing/wavProcessing.py in fft_and_blocks(audioFiles, sampleAudioDirectory)
#     105
#     106         for fileName in audioFiles :
# --> 107                 (digitalSignal, samplingRate) = read_wav_file(fileName, sampleAudioDirectory)
#     108                 signalSize = len(digitalSignal)
#     109
#
# /home/as497/codework/wav-processing/wavProcessing.py in read_wav_file(fileName, directory)
#      16                 if sampleFile == fileName :
#      17                         filePath = directory + fileName
# ---> 18                         (samplingRate, digitalSignal) = wav.read(filePath)
#      19                         return digitalSignal, samplingRate
#      20
#
# /home/as497/anaconda3/lib/python3.5/site-packages/scipy/io/wavfile.py in read(filename, mmap)
#     188         mmap = False
#     189     else:
# --> 190         fid = open(filename, 'rb')
#     191
#     192     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './Sample Audiocarnatic.wav'

# %%
sampleAudioDirectory = './Sample Audio/'

# %%
wp.fft_and_blocks(audioFiles, sampleAudioDirectory)
# Out:
# No. of audio samples in  carnatic.wav  is  150632
# Size of new digital signal:  154350
#
#
#
# No. of audio samples in  mridangam.wav  is  87228
# Size of new digital signal:  88200
#
#
#
# No. of audio samples in  cello-double-2.wav  is  302215
# Size of new digital signal:  308700
#
#
#
# No. of audio samples in  multiSines.wav  is  264600
# Size of new digital signal:  264600
#
#
#
# No. of audio samples in  cello-double.wav  is  225961
# Size of new digital signal:  231525

# %%
# %matplotlib inline

# %%
wp.fft_and_blocks(audioFiles, sampleAudioDirectory)
# Out:
# No. of audio samples in  carnatic.wav  is  150632
# Size of new digital signal:  154350
# No. of audio samples in  mridangam.wav  is  87228
# Size of new digital signal:  88200
# No. of audio samples in  cello-double-2.wav  is  302215
# Size of new digital signal:  308700
# No. of audio samples in  multiSines.wav  is  264600
# Size of new digital signal:  264600
# No. of audio samples in  cello-double.wav  is  225961
# Size of new digital signal:  231525
